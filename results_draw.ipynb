# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path = 'results.xlsx'
df = pd.read_excel(file_path)
df.columns = [
    "days_before_diag", "num_ad_patients", "accuracy_LSTM-D", "precision_LSTM-D", "recall_LSTM-D", "f1_LSTM-D", "roc_auc_LSTM-D",
    "accuracy_RF", "precision_RF", "recall_RF", "f1_RF", "roc_auc_RF",
    "accuracy_DT", "precision_DT", "recall_DT", "f1_DT", "roc_auc_DT",
    "accuracy_LR", "precision_LR", "recall_LR", "f1_LR", "roc_auc_LR"
]

df = df.drop(0).reset_index(drop=True)

for col in df.columns[1:]:
    df[col] = pd.to_numeric(df[col], errors='coerce')

display(df)
# Out:
#    days_before_diag  num_ad_patients  accuracy_LSTM-D  precision_LSTM-D  \
# 0                 0             2510           0.9480            0.9252
# 1                -7             1276           0.8521            0.8247
# 2               -30              857           0.8333            0.8200
# 3               -90              701           0.8462            0.8293
# 4              -180              603           0.8162            0.7416
# 5              -270              546           0.8033            0.7681
# 6              -300              528           0.7712            0.7162
# 7              -330              510           0.8070            0.7692
# 8              -365              488           0.8056            0.7619
# 9              -540              410           0.7174            0.6786
# 10             -730              345           0.6154            0.6552
#
#     recall_LSTM-D  f1_LSTM-D  roc_auc_LSTM-D  accuracy_RF  precision_RF  \
# 0          0.9749     0.9494          0.9637       0.9208        0.9070
# 1          0.8944     0.8581          0.9234       0.8884        0.8721
# 2          0.8542     0.8367          0.9016       0.8580        0.8559
# 3          0.8718     0.8500          0.9011       0.8571        0.8111
# 4          0.9706     0.8408          0.9074       0.8276        0.7952
# 5          0.8689     0.8154          0.8715       0.8365        0.8219
# 6          0.8983     0.7970          0.8940       0.8000        0.7606
# 7          0.8772     0.8197          0.8335       0.7629        0.7397
# 8          0.8889     0.8205          0.8738       0.7634        0.7500
# 9          0.8261     0.7451          0.7802       0.7179        0.7119
# 10         0.6872     0.6588          0.6988       0.6212        0.6383
#
#     recall_RF  ...  accuracy_DT  precision_DT  recall_DT   f1_DT  roc_auc_DT  \
# 0      0.9512  ...       0.8849        0.9065     0.8780  0.8920      0.8855
# 1      0.9677  ...       0.7975        0.8681     0.8065  0.8361      0.7940
# 2      0.9439  ...       0.7716        0.8723     0.7664  0.8159      0.7741
# 3      0.9733  ...       0.7368        0.7857     0.7333  0.7586      0.7374
# 4      0.9565  ...       0.7414        0.8305     0.7101  0.7656      0.7487
# 5      0.9375  ...       0.6827        0.7460     0.7344  0.7402      0.6679
# 6      0.9474  ...       0.7300        0.7551     0.7115  0.7327      0.7308
# 7      0.9310  ...       0.7526        0.7273     0.8163  0.7692      0.6826
# 8      0.9107  ...       0.6989        0.7593     0.7321  0.7455      0.6904
# 9      0.8936  ...       0.6515        0.6829     0.7368  0.7089      0.6363
# 10     0.7895  ...       0.5897        0.6731     0.7000  0.6863      0.5464
#
#     accuracy_LR  precision_LR  recall_LR   f1_LR  roc_auc_LR
# 0        0.7607        0.7682     0.7296  0.7484      0.7600
# 1        0.6612        0.7039     0.8129  0.7574      0.6957
# 2        0.6481        0.6562     0.9813  0.7865      0.6204
# 3        0.6241        0.6106     0.9200  0.7340      0.5899
# 4        0.6121        0.6250     0.8696  0.7273      0.6442
# 5        0.5769        0.6163     0.8281  0.7067      0.5689
# 6        0.6000        0.5977     0.9123  0.7222      0.5777
# 7        0.5979        0.6203     0.8448  0.7153      0.5910
# 8        0.6022        0.6338     0.8036  0.7087      0.5907
# 9        0.5641        0.6176     0.8400  0.7119      0.5386
# 10       0.5152        0.5652     0.6842  0.6190      0.5338
#
# [11 rows x 22 columns]

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x='days_before_diag', y='num_ad_patients', data=df, palette='Blues_d')

plt.xlabel('Days Before Diagnosis')
plt.ylabel('Number of AD Patients')
plt.title('Number of AD Patients by Days Before Diagnosis')

plt.show()
# Out:
# C:\Users\Yizong Xing\AppData\Local\Temp\ipykernel_52868\1446739492.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='days_before_diag', y='num_ad_patients', data=df, palette='Blues_d')
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Yizong Xing\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# Accuracy Graph

# %%
import matplotlib.pyplot as plt
import matplotlib
from contextlib import contextmanager
import pandas as pd
import matplotlib.ticker as ticker
from matplotlib.ticker import FixedLocator
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import Grid



@contextmanager
def toggle_matplotlib():
    original_settings = plt.rcParams.copy()
    try:
        plt.rcParams["axes.unicode_minus"] = False       
        yield
    finally:
        plt.rcParams.update(original_settings)

# %%
def plot_facet(df, metrics, models, nrows=4, ncols=4, figsize=(16, 16), background_color=None):
    colors = matplotlib.colormaps.get_cmap("tab10")
    
    fig = plt.figure(figsize=figsize)
    grid = Grid(fig, rect=111, nrows_ncols=(nrows, ncols), axes_pad=0.02, label_mode='L') 

    for row, metric in enumerate(metrics):
        for col, model in enumerate(models):
            y = df[f"{metric}_{model}"]
            x = df["days_before_diag"]
            
            ax = grid[row * ncols + col]  
            
            ax.plot(x, y, label=f"{metric}_{model}", marker='o', color=colors(col), markersize=3)
            
            for other_model in models:
                if other_model != model:
                    other_y = df[f"{metric}_{other_model}"]
                    ax.plot(x, other_y, color=colors(models.index(other_model)), alpha=0.27)
            
            if background_color is not None:
                ax.set_facecolor(background_color)

            ax.spines["top"].set_visible(False)
            ax.spines["right"].set_visible(False)
            
            # y-axis 
            if col == 0:
                ax.set_ylabel(metric.capitalize(), fontsize=16, fontweight="bold")
                ax.yaxis.tick_left()
                ax.set_yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1.0])
                ax.tick_params(axis='y', labelleft=True, labelright=False, direction='in', pad=0)  
            else:
                ax.spines["left"].set_visible(False)
                ax.yaxis.set_visible(False)  

            if row == 0:
                ax.set_title(model, fontsize=16, fontweight="bold")
            
            if row == 1:
                ax.xaxis.tick_bottom()
                ax.set_xticks([-730, -540, -365, -270, -180, -90, -30, 0])
                ax.tick_params(axis='x', labelbottom=True, labeltop=False, direction='inout', pad=5, rotation=45)  
            else:
                ax.spines["bottom"].set_visible(False)
                ax.xaxis.set_visible(False)

            specific_x_ticks = [-730, -540, -365, -270, -180, -90, -30, 0]
            ax.set_xticks(specific_x_ticks)
            ax.xaxis.set_major_locator(FixedLocator(specific_x_ticks))
            ax.xaxis.set_tick_params(labelbottom=False)

            # specific_y_ticks = []
            specific_y_ticks = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
            ax.set_ylim(0.5, 1.0)
            ax.yaxis.set_major_locator(FixedLocator(specific_y_ticks))
            ax.yaxis.set_tick_params(labelbottom=False)

            for tick in ax.get_xticks():
                ax.axvline(x=tick, color='gray', linestyle='--', linewidth=0.5, alpha=0.4)

            for tick in ax.get_yticks():
                ax.axhline(y=tick, color='gray', linestyle='--', linewidth=0.5, alpha=0.4)

    fig.text(0.5, 0.02, 'Days Before Diagnosis', ha='center', fontsize=16)

    plt.tight_layout(rect=[0.05, 0.05, 1, 1])  
    return fig

# %%
metrics = ["accuracy", "recall", "f1", "roc_auc"]
models = ["LSTM-D", "RF", "DT", "LR"]

with toggle_matplotlib():
    fig = plot_facet(df, metrics, models, nrows=4, ncols=4, figsize=(16, 9), background_color="#ffffff")
    # "#f6f6f6" #f9fff3
    plt.show()

# %%
import numpy as np

file_path = "itemid_to_vector.csv"
df_itemid_to_vector = pd.read_csv(file_path)
itemid_to_vector = {str(key): value for key, value in df_itemid_to_vector.set_index('itemid').T.to_dict('list').items()}

# %%
pairs = [(["51087", "Length of Urine\nCollection"], ["51108","Urine Volume"]), 
         (["51101", "Total Collection Time"], ["51109", "Urine Volume, Total"]), 
         (["52285", "RBC, CSF"], ["51790", "Glucose, CSF"]), 
         (["51180", "CD4 Cells, Percent"], ["51181", "CD4/CD8 Ratio"])]

def prepare_radar_data(itemid_pair, itemid_to_vector):
    vectors = [itemid_to_vector[itemid[0]] for itemid in itemid_pair]
    labels = [f"D{i+1}" for i in range(len(vectors[0]))]
    num_vars = len(labels)
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    angles += angles[:1]  
    vectors = [vector + [vector[0]] for vector in vectors]  
    return labels, angles, vectors

fig, axes = plt.subplots(1, 4, figsize=(20, 7), subplot_kw=dict(polar=True))
# fig.suptitle("Radar Charts of ItemID Pairs", fontsize=16)

for ax, (itemid1, itemid2) in zip(axes, pairs):
    labels, angles, vectors = prepare_radar_data((itemid1, itemid2), itemid_to_vector)
    for vector, itemid in zip(vectors, [itemid1, itemid2]):
        ax.plot(angles, vector, label=f"{itemid[0]} {itemid[1]}")
        ax.fill(angles, vector, alpha=0.2)
    ax.set_yticklabels([])
    ax.set_xticks(angles[:-1])
    # ax.set_xticklabels(labels, fontsize=15)
    ax.set_xticklabels([])
    # ax.set_title(f"{itemid1[0]} & {itemid2[0]}", fontsize=16)

    ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.27), prop={'size': 18})

plt.subplots_adjust(wspace=0.001)
plt.tight_layout()
plt.show()
