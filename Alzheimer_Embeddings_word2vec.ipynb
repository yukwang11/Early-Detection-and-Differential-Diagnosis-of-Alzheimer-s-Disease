# %% [markdown]
# # **Get embeddings of labtests**

# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/ML4Health/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load libraries and setup environment

# %%
# !pip install tslearn
# !pip install minisom



from sklearn.cluster import AgglomerativeClustering
from minisom import MiniSom

from datetime import timedelta
import os

import numpy as np
import pandas as pd
import seaborn as sns
import os

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.decomposition import PCA #Principal Component Analysis
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

import re
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from IPython.display import display, HTML, Image
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams.update({'font.size': 20})

# Access data using Google BigQuery.
from google.colab import auth
from google.cloud import bigquery

import bigframes.pandas as bf
import matplotlib.pyplot as plt
import plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.io as pio
pio.renderers.default = "colab"

from gensim.models import Word2Vec

from IPython.display import clear_output

import torch

import copy
import datetime
import sys

bf.options.bigquery.location = "US"
bf.options.bigquery.project = 'hellobigquery-431508'
# Out:
# Collecting tslearn
#   Downloading tslearn-0.6.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.5.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.60.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.5.0)
# Downloading tslearn-0.6.3-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: tslearn
# Successfully installed tslearn-0.6.3
# Collecting minisom
#   Downloading MiniSom-2.3.3.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: minisom
#   Building wheel for minisom (setup.py) ... done
#   Created wheel for minisom: filename=MiniSom-2.3.3-py3-none-any.whl size=11706 sha256=a5acf7a2c57a88751aba8a5cb6168722c0488c7285faf6b39897bc0ccdc114a1
#   Stored in directory: /root/.cache/pip/wheels/96/98/a5/52dee3e8ed1dbfc4d77e4da41b6d89dd7ab9ead1b921e766f8
# Successfully built minisom
# Installing collected packages: minisom
# Successfully installed minisom-2.3.3

# %%
# authenticate
auth.authenticate_user()

project_id = 'hellobigquery-431508'
os.environ["GOOGLE_CLOUD_PROJECT"] = project_id
dataset = 'mimiciv'

# %% [markdown]
# ## **Find patients with AD related ICD codes.**

# %% [markdown]
# Load all diagnoses icd table, and filter with our event list:

# %%
query = """
  SELECT
    d.*,
    a.dischtime AS discharge_time
  FROM
    `physionet-data.mimiciv_hosp.diagnoses_icd` AS d
  INNER JOIN
    `physionet-data.mimiciv_hosp.admissions` AS a
  ON
    d.hadm_id = a.hadm_id
  WHERE
    d.icd_code IN ('G300', 'G301', 'G308', 'G309', 'F0280', 'F0281', 'F0290', 'F0391', 'F04',
      'F060', 'F068', 'G3101', 'G3109', 'G311', 'G3183', 'G3185', 'G3189', 'G319',
      'G454', 'G937', 'G94', 'G910', 'G911', 'G912', 'F0150', 'F0151', 'I675',
      'I671', 'I672', 'I674', 'I676', 'I677', 'I6781', 'I6782', 'I6789', 'I679')

"""
df_ad_patients_with_discharge_time = bf.read_gbq(query)
print(len(df_ad_patients_with_discharge_time))
df_ad_patients_with_discharge_time.head(10)

# WHERE
    # d.icd_code IN ('G300', 'G301', 'G308', 'G309', 'F0280', 'F0281', 'F0290', 'F0391', 'F04',
    # 'F060', 'F068', 'G3101', 'G3109', 'G311', 'G3183', 'G3185', 'G3189', 'G319',
    # 'G454', 'G937', 'G94', 'G910', 'G911', 'G912', 'F0150', 'F0151', 'I675',
    # 'I671', 'I672', 'I674', 'I676', 'I677', 'I6781', 'I6782', 'I6789', 'I679',
    # '29012', '331', '2904', '29041', '29042', '29043', '294', '2948', '2949',
    # '2941', '29411', '2942', '29421', '3312', '3316', '3317', '33111', '33119',
    # '33181', '33182', '33189', '4377', '3313', '3314', '3315', '437', '4371',
    # '4372', '4373', '4374', '4375', '4376', '4378', '4379', '33183', '331',
    # '3311' )
# Out:
# Query job 54828f5f-9a0e-454c-9ba7-edbd7495fd47 is DONE. 190.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:54828f5f-9a0e-454c-9ba7-edbd7495fd47&page=queryresults">Open Job</a>
# 7420
# Query job bf8d7b49-566b-403e-ba0f-7eb101c1bd56 is DONE. 345.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:bf8d7b49-566b-403e-ba0f-7eb101c1bd56&page=queryresults">Open Job</a>
# Query job d5c8af02-8385-4b0e-b120-addf69a6e88d is DONE. 627 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:d5c8af02-8385-4b0e-b120-addf69a6e88d&page=queryresults">Open Job</a>
#    subject_id   hadm_id  seq_num icd_code  icd_version       discharge_time
# 0    17933761  20476026        4    F0280           10  2112-11-08 12:20:00
# 1    14945936  26868663        5    F0391           10  2203-05-28 15:32:00
# 2    19865666  27925490       13    F0280           10  2152-05-14 16:57:00
# 3    10707442  23962945        4    F0280           10  2147-06-21 14:38:00
# 4    19021878  20406937        9    F0280           10  2173-02-22 13:33:00
# 5    12864680  21022399       14    G3183           10  2144-10-11 15:02:00
# 6    15380556  27064881        1     I671           10  2141-08-30 15:45:00
# 7    14125217  22678449       10     I672           10  2182-06-27 15:30:00
# 8    19454731  23586324        3     I671           10  2134-08-02 17:50:00
# 9    18497825  23119353       14    F0280           10  2177-01-02 11:15:00
#
# [10 rows x 6 columns]

# %%
# df_ad_patients_with_discharge_time.head(10)

# %%
ad_patients_list = list(df_ad_patients_with_discharge_time.drop_duplicates(subset=['subject_id'])['subject_id'])
len(ad_patients_list)
# df_ad_patients
# Out:
# Query job 8b7c9dab-63ca-4fb5-86a0-3ec0285cd04b is DONE. 345.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:8b7c9dab-63ca-4fb5-86a0-3ec0285cd04b&page=queryresults">Open Job</a>
# Query job ef5be9d3-6a73-493c-910d-11df31b575bc is DONE. 345.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:ef5be9d3-6a73-493c-910d-11df31b575bc&page=queryresults">Open Job</a>
# 3947

# %% [markdown]
# ## Possible Tests

# %% [markdown]
# ## **See what tests are taken by these patients**

# %%
# See what labtests are taken for these patients

query = """
  SELECT
    d.subject_id,
    d.hadm_id,
    d.icd_code,
    d.icd_version,
    l.itemid,
    l.valuenum,
    l.valueuom,
    l.labevent_id,
    l.charttime,
    l.flag,
    dlab.label,
    dlab.fluid,
    dlab.category
  FROM
    (
      SELECT subject_id, hadm_id, icd_code, icd_version
      FROM `physionet-data.mimiciv_hosp.diagnoses_icd`
      WHERE icd_code IN ('G300', 'G301', 'G308', 'G309', 'F0280', 'F0281', 'F0290', 'F0391', 'F04',
            'F060', 'F068', 'G3101', 'G3109', 'G311', 'G3183', 'G3185', 'G3189', 'G319',
            'G454', 'G937', 'G94', 'G910', 'G911', 'G912', 'F0150', 'F0151', 'I675',
            'I671', 'I672', 'I674', 'I676', 'I677', 'I6781', 'I6782', 'I6789', 'I679')
    ) AS d
  INNER JOIN
    (
      SELECT subject_id, hadm_id, labevent_id, itemid, valuenum, valueuom, charttime, flag
      FROM `physionet-data.mimiciv_hosp.labevents`
      WHERE lower(flag) LIKE 'abnormal%'
        OR flag IS NULL
    ) AS l
  ON
    d.subject_id = l.subject_id
    AND d.hadm_id = l.hadm_id
  INNER JOIN
    `physionet-data.mimiciv_hosp.d_labitems` AS dlab
  ON
    l.itemid = dlab.itemid
    WHERE l.valuenum IS NOT NULL  -- remove NULL values
  # WHERE (LOWER(dlab.label) LIKE '%csf' OR
  #  LOWER(dlab.label) LIKE'%b12%')
"""
df_ad_patients_lab_results = bf.read_gbq(query).sort_values(by=['subject_id', 'charttime', 'labevent_id']).reset_index(drop=True)
print(len(df_ad_patients_lab_results))
df_ad_patients_lab_results.head(10)
# Out:
# Query job ada49914-fa13-4b63-8be4-f0e22aef0b7d is DONE. 6.1 GB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:ada49914-fa13-4b63-8be4-f0e22aef0b7d&page=queryresults">Open Job</a>
# 1385974
# Query job f4b09a34-e808-4078-a1c3-91a92e6c4bc3 is DONE. 139.6 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:f4b09a34-e808-4078-a1c3-91a92e6c4bc3&page=queryresults">Open Job</a>
# Query job 09c74767-9479-4a4b-9887-b0bd90950c03 is DONE. 1.2 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:09c74767-9479-4a4b-9887-b0bd90950c03&page=queryresults">Open Job</a>
#    subject_id   hadm_id icd_code  icd_version  itemid  valuenum valueuom  \
# 0    10000084  23052089    F0280           10   51133      2.86     K/uL
# 1    10000084  23052089    G3183           10   51133      2.86     K/uL
# 2    10000084  23052089    F0280           10   51146       0.6        %
# 3    10000084  23052089    G3183           10   51146       0.6        %
# 4    10000084  23052089    G3183           10   51200       2.0        %
# 5    10000084  23052089    F0280           10   51200       2.0        %
# 6    10000084  23052089    G3183           10   51221      38.2        %
# 7    10000084  23052089    F0280           10   51221      38.2        %
# 8    10000084  23052089    G3183           10   51222      12.8     g/dL
# 9    10000084  23052089    F0280           10   51222      12.8     g/dL
#
#    labevent_id            charttime      flag                      label  \
# 0          672  2160-11-20 22:30:00      <NA>  Absolute Lymphocyte Count
# 1          672  2160-11-20 22:30:00      <NA>  Absolute Lymphocyte Count
# 2          673  2160-11-20 22:30:00      <NA>                  Basophils
# 3          673  2160-11-20 22:30:00      <NA>                  Basophils
# 4          674  2160-11-20 22:30:00      <NA>                Eosinophils
# 5          674  2160-11-20 22:30:00      <NA>                Eosinophils
# 6          675  2160-11-20 22:30:00  abnormal                 Hematocrit
# 7          675  2160-11-20 22:30:00  abnormal                 Hematocrit
# 8          676  2160-11-20 22:30:00  abnormal                 Hemoglobin
# 9          676  2160-11-20 22:30:00  abnormal                 Hemoglobin
#
#    fluid    category
# 0  Blood  Hematology
# 1  Blood  Hematology
# 2  Blood  Hematology
# 3  Blood  Hematology
# 4  Blood  Hematology
# 5  Blood  Hematology
# 6  Blood  Hematology
# 7  Blood  Hematology
# 8  Blood  Hematology
# 9  Blood  Hematology
#
# [10 rows x 13 columns]

# %% [markdown]
# For each patient, only keep the test data with charttime before their diagnoses' dischargetime

# %%
df_temp = df_ad_patients_with_discharge_time[['subject_id', 'hadm_id', 'discharge_time']].drop_duplicates(subset=['subject_id', 'hadm_id']).to_pandas()
df_ad_patients_lab_results_pd = df_ad_patients_lab_results.to_pandas()

df_ad_patients_lab_results_pd = pd.merge(df_ad_patients_lab_results_pd, df_temp, on=['subject_id', 'hadm_id'], how='left')

df_ad_patients_lab_results_pd = df_ad_patients_lab_results_pd[df_ad_patients_lab_results_pd['charttime'] <= df_ad_patients_lab_results_pd['discharge_time']].reset_index(drop=True)

print(len(df_ad_patients_lab_results_pd))
df_ad_patients_lab_results_pd.head(10)
# Out:
# Query job d515a04d-b12f-4313-833a-1afac61c71bd is DONE. 345.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:d515a04d-b12f-4313-833a-1afac61c71bd&page=queryresults">Open Job</a>
# Query job 8673f644-b9c8-46f5-86f1-b1e5f4ba7a09 is DONE. 139.6 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:8673f644-b9c8-46f5-86f1-b1e5f4ba7a09&page=queryresults">Open Job</a>
# 1385218
#    subject_id   hadm_id icd_code  icd_version  itemid  valuenum valueuom  \
# 0    10000084  23052089    F0280           10   51133      2.86     K/uL
# 1    10000084  23052089    G3183           10   51133      2.86     K/uL
# 2    10000084  23052089    F0280           10   51146       0.6        %
# 3    10000084  23052089    G3183           10   51146       0.6        %
# 4    10000084  23052089    G3183           10   51200       2.0        %
# 5    10000084  23052089    F0280           10   51200       2.0        %
# 6    10000084  23052089    G3183           10   51221      38.2        %
# 7    10000084  23052089    F0280           10   51221      38.2        %
# 8    10000084  23052089    G3183           10   51222      12.8     g/dL
# 9    10000084  23052089    F0280           10   51222      12.8     g/dL
#
#    labevent_id            charttime      flag                      label  \
# 0          672  2160-11-20 22:30:00      <NA>  Absolute Lymphocyte Count
# 1          672  2160-11-20 22:30:00      <NA>  Absolute Lymphocyte Count
# 2          673  2160-11-20 22:30:00      <NA>                  Basophils
# 3          673  2160-11-20 22:30:00      <NA>                  Basophils
# 4          674  2160-11-20 22:30:00      <NA>                Eosinophils
# 5          674  2160-11-20 22:30:00      <NA>                Eosinophils
# 6          675  2160-11-20 22:30:00  abnormal                 Hematocrit
# 7          675  2160-11-20 22:30:00  abnormal                 Hematocrit
# 8          676  2160-11-20 22:30:00  abnormal                 Hemoglobin
# 9          676  2160-11-20 22:30:00  abnormal                 Hemoglobin
#
#    fluid    category       discharge_time
# 0  Blood  Hematology  2160-11-25 14:52:00
# 1  Blood  Hematology  2160-11-25 14:52:00
# 2  Blood  Hematology  2160-11-25 14:52:00
# 3  Blood  Hematology  2160-11-25 14:52:00
# 4  Blood  Hematology  2160-11-25 14:52:00
# 5  Blood  Hematology  2160-11-25 14:52:00
# 6  Blood  Hematology  2160-11-25 14:52:00
# 7  Blood  Hematology  2160-11-25 14:52:00
# 8  Blood  Hematology  2160-11-25 14:52:00
# 9  Blood  Hematology  2160-11-25 14:52:00

# %%
df_ad_patients_lab_results_pd = df_ad_patients_lab_results.to_pandas()
df_ad_patients_lab_results_pd['itemid'] = df_ad_patients_lab_results_pd['itemid'].astype(str)
df_ad_patients_lab_results_pd.dtypes
# Out:
# Query job 4b059771-17e4-48a9-b020-5f9994001ec0 is DONE. 139.6 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:4b059771-17e4-48a9-b020-5f9994001ec0&page=queryresults">Open Job</a>
# subject_id                      Int64
# hadm_id                         Int64
# icd_code              string[pyarrow]
# icd_version                     Int64
# itemid                         object
# valuenum                      Float64
# valueuom              string[pyarrow]
# labevent_id                     Int64
# charttime      timestamp[us][pyarrow]
# flag                  string[pyarrow]
# label                 string[pyarrow]
# fluid                 string[pyarrow]
# category              string[pyarrow]
# dtype: object

# %%
# see how many unique patients:
print(len(df_ad_patients_lab_results_pd['subject_id'].unique()))
# Out:
# 3764

# %%
possible_tests = bf.read_gbq("""
  SELECT *
  FROM `physionet-data.mimiciv_hosp.d_labitems`
""")
ad_tests = list(set(df_ad_patients_lab_results['itemid']))
ad_test_names = possible_tests[possible_tests['itemid'].isin(ad_tests)].to_pandas()
ad_test_names['itemid'] = ad_test_names['itemid'].astype(str)

ad_test_names.head(1)
# Out:
# Query job 8e61ca4d-9938-49e4-ae4b-55eb480366ca is DONE. 71.1 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:8e61ca4d-9938-49e4-ae4b-55eb480366ca&page=queryresults">Open Job</a>
# Query job 2e3e478f-b1f7-4f0e-9d12-314009c2c85b is DONE. 139.6 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:2e3e478f-b1f7-4f0e-9d12-314009c2c85b&page=queryresults">Open Job</a>
# Query job 5c666271-a273-4d02-8a3d-70817fbc87f7 is DONE. 71.1 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:5c666271-a273-4d02-8a3d-70817fbc87f7&page=queryresults">Open Job</a>
#   itemid      label  fluid    category
# 5  51203  Factor IX  Blood  Hematology

# %%
itemid_counts_df = df_ad_patients_lab_results_pd.groupby('itemid')['subject_id'].nunique().reset_index()
itemid_counts_df.columns = ['itemid', 'count']
itemid_counts_df['itemid'] = itemid_counts_df['itemid'].astype(str)


merged_df = pd.merge(itemid_counts_df, ad_test_names, on='itemid', how='inner')

merged_df_sorted = merged_df.sort_values(by='count', ascending=False)

merged_df_sorted
# Out:
#     itemid  count                    label    fluid    category
# 70   50912   3729               Creatinine    Blood   Chemistry
# 130  51006   3728            Urea Nitrogen    Blood   Chemistry
# 107  50971   3727                Potassium    Blood   Chemistry
# 60   50902   3722                 Chloride    Blood   Chemistry
# 46   50882   3722              Bicarbonate    Blood   Chemistry
# ..     ...    ...                      ...      ...         ...
# 377  52129      1         Hemoglobin Other    Blood  Hematology
# 352  51772      1                     PAN3    Blood   Chemistry
# 33   50850      1   Triglycerides, Ascites  Ascites   Chemistry
# 156  51072      1           Amylase, Urine    Urine   Chemistry
# 378  52132      1  HIT-Ab Numerical Result    Blood  Hematology
#
# [406 rows x 5 columns]

# %% [markdown]
# ### **Apply Word2vec embedding, treating each patient's test history as a "sentence" and each labtest as a "word".**

# %% [markdown]
# Prepare the sentences:

# %%
query = """
    SELECT
        subject_id,
        STRING_AGG(CAST(itemid AS STRING) ORDER BY charttime ASC) AS itemid_sequence,  -- ASC for time order
        ARRAY_AGG(CAST(valuenum AS FLOAT64) ORDER BY charttime ASC) AS test_value_sequence,  -- ASC for time order
        ARRAY_LENGTH(ARRAY_AGG(itemid ORDER BY charttime ASC)) AS sequence_length,
        STRING_AGG(DISTINCT icd_code ORDER BY icd_code ASC) AS icd_codes,
        'mimic_iv' AS data_source,  -- New column with constant value 'mimic_iv'
        CASE
            WHEN REGEXP_CONTAINS(STRING_AGG(DISTINCT icd_code ORDER BY icd_code ASC), r'G30.*')
            THEN 1
            ELSE 0
        END AS label_ad  -- New column that marks Alzheimer's Disease based on G30 ICD codes
    FROM (
        SELECT
            d.subject_id,
            l.itemid,
            l.valuenum,
            l.charttime,
            d.icd_code,
            ROW_NUMBER() OVER (PARTITION BY d.subject_id, l.itemid ORDER BY l.charttime DESC) AS rn
        FROM
            physionet-data.mimiciv_hosp.diagnoses_icd AS d
        JOIN
            physionet-data.mimiciv_hosp.labevents AS l
        ON
            d.subject_id = l.subject_id
        JOIN
            physionet-data.mimiciv_hosp.admissions AS a
        ON
            l.hadm_id = a.hadm_id
        INNER JOIN
          `physionet-data.mimiciv_hosp.d_labitems` AS dlab
        ON
          l.itemid = dlab.itemid
        WHERE
            (
              d.icd_code LIKE 'G30%' OR
              d.icd_code LIKE 'F01%' OR
              d.icd_code LIKE 'F03%' OR
              d.icd_code LIKE 'F02%' OR
              d.icd_code LIKE 'R54%' OR

              d.icd_code IN ('G318', 'G310', 'G311', 'G318', 'G319', '3310', '3311', '3312', '3319', '2904', '2900', '2901', '2902', '2903', '2908', '2909', '797')
            )
            AND l.valuenum IS NOT NULL
            AND l.charttime <= a.dischtime
            AND (LOWER(l.flag) LIKE 'abnormal%' OR l.flag IS NULL)
            # AND LOWER(dlab.label) NOT LIKE '%csf'
    ) AS filtered
    # WHERE
    #     rn <= 2  -- only keep the first two entries for each itemid per patient
    GROUP BY
        subject_id
    ORDER BY
        subject_id;
"""




df_itemid_sequences_4 = bf.read_gbq(query)
print(len(df_itemid_sequences_4))
df_itemid_sequences_4.head(10)
# Out:
# Query job 5b510774-c23e-4258-9c0e-11455ad28ec5 is DONE. 4.5 GB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:5b510774-c23e-4258-9c0e-11455ad28ec5&page=queryresults">Open Job</a>
# 6099
# Query job 9f856541-2c9f-4493-a720-c803453dcc75 is DONE. 111.8 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:9f856541-2c9f-4493-a720-c803453dcc75&page=queryresults">Open Job</a>
# Query job a68ad8a5-6a5f-46c7-97b8-bd9e8ed90250 is DONE. 84.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:a68ad8a5-6a5f-46c7-97b8-bd9e8ed90250&page=queryresults">Open Job</a>
#    subject_id                                    itemid_sequence  \
# 0    16270291  51301,50902,50893,50960,51222,51003,51249,5100...
# 1    15165614  51222,50911,51248,51275,50983,51249,50893,5127...
# 2    13786618  51255,51255,50878,50878,50863,50863,50971,5097...
# 3    11603984  50868,50971,50970,51277,51250,50893,50960,5124...
# 4    14491605  51222,51222,51678,51678,51301,51301,50983,5098...
# 5    11502644  51498,51498,51482,51482,51478,51478,51493,5149...
# 6    15702242  51265,51265,51250,51250,51279,51279,51277,5127...
# 7    18968832  50813,50813,51265,50956,51301,50861,50971,5125...
# 8    16162028  51250,50960,51221,51265,50868,50983,50931,5097...
# 9    11132352  51275,50902,51301,51250,51237,51249,51275,5093...
#
#                                  test_value_sequence  sequence_length  \
# 0  [1.010e+01 1.000e+02 9.300e+00 1.700e+00 1.090...               66
# 1  [1.240e+01 4.000e+00 3.230e+01 2.950e+01 1.420...              220
# 2          [  0.    0.   29.  ... 403.   16.6  16.6]             1406
# 3  [ 1.50e+01  4.60e+00  3.70e+00  1.26e+01  8.90...              392
# 4  [1.16e+01 1.16e+01 3.00e+00 3.00e+00 5.50e+00 ...              198
# 5  [1.018e+00 1.018e+00 1.000e+00 1.000e+00 1.500...              838
# 6          [259.  259.   90.  ... 146.   27.6  27.6]             1590
# 7  [2.90e+00 2.90e+00 4.86e+02 3.17e+03 1.64e+01 ...              112
# 8  [8.600e+01 1.600e+00 3.500e+01 2.810e+02 1.900...              632
# 9  [8.480e+01 1.040e+02 4.300e+00 8.800e+01 1.100...              540
#
#     icd_codes data_source  label_ad
# 0        2900    mimic_iv         0
# 1       F0390    mimic_iv         0
# 2        3310    mimic_iv         0
# 3       F0390    mimic_iv         0
# 4  F0280,G309    mimic_iv         1
# 5       F0150    mimic_iv         0
# 6  F0280,G309    mimic_iv         1
# 7        3310    mimic_iv         0
# 8       F0390    mimic_iv         0
# 9        3310    mimic_iv         0
#
# [10 rows x 7 columns]

# %%
df_labtest_sequences_pd_4 = df_itemid_sequences_4.to_pandas()
sns.displot(df_itemid_sequences_4['sequence_length'])
# Out:
# Query job 743d313d-87bb-4335-9b72-7d7f291bbfef is DONE. 111.8 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:743d313d-87bb-4335-9b72-7d7f291bbfef&page=queryresults">Open Job</a>
# Query job 2bdae7c6-2a2a-4ee7-80fb-911eacf09238 is DONE. 111.8 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:2bdae7c6-2a2a-4ee7-80fb-911eacf09238&page=queryresults">Open Job</a>
# Query job 69df53b9-3ae6-41a8-9f03-b2e1fa6e70bb is DONE. 111.8 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:69df53b9-3ae6-41a8-9f03-b2e1fa6e70bb&page=queryresults">Open Job</a>

# %%
print(df_itemid_sequences_4['sequence_length'].max())
print(df_itemid_sequences_4['sequence_length'].min())
# Out:
# Query job 2dda34d1-ac60-4b8f-96cf-e160927a26be is DONE. 48.8 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:2dda34d1-ac60-4b8f-96cf-e160927a26be&page=queryresults">Open Job</a>
# 185526
# Query job a94321cb-3795-427c-95ed-c20283fb949c is DONE. 48.8 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:a94321cb-3795-427c-95ed-c20283fb949c&page=queryresults">Open Job</a>
# 1

# %%
print(df_itemid_sequences_4.dtypes)
# Out:
# subject_id                                   Int64
# itemid_sequence                    string[pyarrow]
# test_value_sequence    list<item: double>[pyarrow]
# sequence_length                              Int64
# icd_codes                          string[pyarrow]
# data_source                        string[pyarrow]
# label_ad                                     Int64
# dtype: object

# %% [markdown]
# ### **Similarly for MIMIC_III**

# %%
query = """
    SELECT
        subject_id,
        STRING_AGG(CAST(itemid AS STRING) ORDER BY charttime ASC) AS itemid_sequence,  -- ASC for time order
        ARRAY_AGG(CAST(valuenum AS FLOAT64) ORDER BY charttime ASC) AS test_value_sequence,  -- ASC for time order
        ARRAY_LENGTH(ARRAY_AGG(itemid ORDER BY charttime ASC)) AS sequence_length,
        STRING_AGG(DISTINCT icd9_code ORDER BY icd9_code ASC) AS icd_codes,
        'mimic_iii' AS data_source,
        CASE WHEN STRING_AGG(DISTINCT icd9_code ORDER BY icd9_code ASC) LIKE '%331%' THEN 1 ELSE 0 END AS label_ad
    FROM (
        SELECT
            d.subject_id,
            l.itemid,
            l.valuenum,
            l.charttime,
            d.icd9_code,
            ROW_NUMBER() OVER (PARTITION BY d.subject_id, l.itemid ORDER BY l.charttime DESC) AS rn
        FROM
            `physionet-data.mimiciii_clinical.diagnoses_icd` AS d
        JOIN
            `physionet-data.mimiciii_clinical.labevents` AS l
        ON
            d.subject_id = l.subject_id
        JOIN
            `physionet-data.mimiciii_clinical.admissions` AS a
        ON
            l.hadm_id = a.hadm_id
        INNER JOIN
          `physionet-data.mimiciii_clinical.d_labitems` AS dlab
        ON
          l.itemid = dlab.itemid
        WHERE
            d.icd9_code LIKE '331%'  -- ICD-9 codes for Alzheimer's and related diseases
            AND l.valuenum IS NOT NULL
            AND l.charttime <= a.dischtime
            AND (LOWER(l.flag) LIKE 'abnormal%' OR l.flag IS NULL)
            # AND LOWER(dlab.label) NOT LIKE '%csf%'
    ) AS filtered
    # WHERE
    #     rn <= 2  -- only keep the first two entries for each itemid per patient
    GROUP BY
        subject_id
    ORDER BY
        subject_id;
"""
df_itemid_sequences_3 = bf.read_gbq(query)
print(len(df_itemid_sequences_3))
df_itemid_sequences_3.head(10)
# Out:
# Query job 94417a46-c0e9-4f1d-aa74-aedfc5bf9532 is DONE. 1.2 GB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:94417a46-c0e9-4f1d-aa74-aedfc5bf9532&page=queryresults">Open Job</a>
# 1246
# Query job 23b7da23-b587-45b0-97fc-1343d8929403 is DONE. 11.5 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:23b7da23-b587-45b0-97fc-1343d8929403&page=queryresults">Open Job</a>
# Query job a27bdb08-d2e2-459e-a965-03f2e9b09cba is DONE. 48.1 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:a27bdb08-d2e2-459e-a965-03f2e9b09cba&page=queryresults">Open Job</a>
#    subject_id                                    itemid_sequence  \
# 0       31403  51254,50970,51249,50882,51248,50993,51146,5096...
# 1       88008  50882,50868,51222,51274,51237,51006,50983,5127...
# 2       11388  51248,51006,51221,51277,51214,51301,51250,5086...
# 3       14129  51244,51254,51146,50882,50902,50924,51277,5124...
# 4       17374  51516,51514,51491,50931,50809,50868,50902,5091...
# 5       12713  50971,51254,51265,51244,51003,51237,51279,5086...
# 6       76056  51237,51275,51277,51274,51200,51250,51254,5097...
# 7        2708  50911,51516,51492,51493,51491,51478,51498,5082...
# 8        8829  51254,50931,51256,51251,51244,51277,51237,5114...
# 9        7367  51237,51301,50868,51237,51254,50971,51256,5124...
#
#                                  test_value_sequence  sequence_length  \
# 0  [3.600e+00 3.200e+00 3.170e+01 3.000e+01 2.640...              248
# 1  [2.0000e+01 1.8000e+01 1.4100e+01 1.2600e+01 1...              755
# 2  [3.050e+01 1.200e+01 3.980e+01 1.420e+01 3.170...              278
# 3  [9.600e+00 1.700e+00 1.000e-01 2.400e+01 1.100...              138
# 4  [0.000e+00 2.000e-01 5.000e+00 9.820e+02 9.800...              220
# 5  [4.100e+00 8.000e+00 1.680e+02 1.590e+01 7.000...              609
# 6  [1.100e+00 2.610e+01 1.330e+01 1.250e+01 6.000...              220
# 7  [ 2.200e+01  4.300e+01  3.000e+01  2.000e+00  ...              382
# 8  [ 7.000e+00  1.800e+02  9.200e+01  0.000e+00  ...              409
# 9  [1.600e+00 6.100e+00 1.500e+01 1.400e+00 4.700...              134
#
#   icd_codes data_source  label_ad
# 0      3310   mimic_iii         1
# 1      3314   mimic_iii         1
# 2      3313   mimic_iii         1
# 3      3310   mimic_iii         1
# 4      3310   mimic_iii         1
# 5      3314   mimic_iii         1
# 6     33182   mimic_iii         1
# 7      3310   mimic_iii         1
# 8      3310   mimic_iii         1
# 9     33182   mimic_iii         1
#
# [10 rows x 7 columns]

# %%
df_labtest_sequences_pd_3 = df_itemid_sequences_3.to_pandas()
sns.displot(df_labtest_sequences_pd_3['sequence_length'])
# Out:
# Query job 1fc8c9f4-0fca-4884-9bb4-435554917b0b is DONE. 11.5 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:1fc8c9f4-0fca-4884-9bb4-435554917b0b&page=queryresults">Open Job</a>

# %%
print(df_labtest_sequences_pd_3.head())
# Out:
#    subject_id                                    itemid_sequence  \
# 0       31403  51254,50970,51249,50882,51248,50993,51146,5096...
# 1       88008  50882,50868,51222,51274,51237,51006,50983,5127...
# 2       11388  51248,51006,51221,51277,51214,51301,51250,5086...
# 3       14129  51244,51254,51146,50882,50902,50924,51277,5124...
# 4       17374  51516,51514,51491,50931,50809,50868,50902,5091...
#
#                                  test_value_sequence  sequence_length  \
# 0  [3.600e+00 3.200e+00 3.170e+01 3.000e+01 2.640...              248
# 1  [2.0000e+01 1.8000e+01 1.4100e+01 1.2600e+01 1...              755
# 2  [3.050e+01 1.200e+01 3.980e+01 1.420e+01 3.170...              278
# 3  [9.600e+00 1.700e+00 1.000e-01 2.400e+01 1.100...              138
# 4  [0.000e+00 2.000e-01 5.000e+00 9.820e+02 9.800...              220
#
#   icd_codes data_source  label_ad
# 0      3310   mimic_iii         1
# 1      3314   mimic_iii         1
# 2      3313   mimic_iii         1
# 3      3310   mimic_iii         1
# 4      3310   mimic_iii         1

# %% [markdown]
# **Combine data fromo mimic iii and iv**

# %%
# df_labtest_sequences_pd = df_itemid_sequences.to_pandas()
df_labtest_sequences_pd = pd.concat([df_labtest_sequences_pd_4, df_labtest_sequences_pd_3], ignore_index=True)

import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

plt.rcParams.update({'font.size': 8})

sns.displot(df_labtest_sequences_pd['sequence_length'], kde=True, color='#00BFFF')

skewness = df_labtest_sequences_pd['sequence_length'].skew()
print(f'Skewness: {skewness}')

plt.title(f'Sequence Length Distribution with Skewness = {skewness:.2f}')

# sns.histplot(data, kde=True)

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Skewness: 19.576489817698963

# %% [markdown]
# **Split itemid sequences, save dataframe**

# %%
import ast


df_labtest_sequences_pd['itemid_sequence'] = df_labtest_sequences_pd['itemid_sequence'].apply(lambda x: x.split(',') if isinstance(x, str) else [])
# df_labtest_sequences_pd['test_value_sequence'] = df_labtest_sequences_pd['test_value_sequence'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else [])
# df_labtest_sequences_pd.to_csv(file_path + 'df_labtest_sequences_pd.csv', index=False)

patients_itemid_seqs = df_labtest_sequences_pd['itemid_sequence']
patients_itemid_seqs[:1]
# Out:
# 0    [51301, 50902, 50893, 50960, 51222, 51003, 512...
# Name: itemid_sequence, dtype: object

# %%
# df_labtest_sequences_pd = pd.read_csv('df_labtest_sequences_pd.csv')
print(len(df_labtest_sequences_pd))
df_labtest_sequences_pd.head(1)
# Out:
# 7345
#    subject_id                                    itemid_sequence  \
# 0    16270291  [51301, 50902, 50893, 50960, 51222, 51003, 512...
#
#                                  test_value_sequence  sequence_length  \
# 0  [1.010e+01 1.000e+02 9.300e+00 1.700e+00 1.090...               66
#
#   icd_codes data_source  label_ad
# 0      2900    mimic_iv         0

# %% [markdown]
# ## **Apply Word2vec embedding, treating each patient's test history as a "sentence" and each labtest as a "word".**

# %%
# from gensim.models import Word2Vec

# w2v_model = Word2Vec(sentences=patients_itemid_seqs, vector_size=20, window=5, sg=1, workers=4, negative=5)
# labevent_vectors = w2v_model.wv
# labevent_ids = list(labevent_vectors.index_to_key)
# print(labevent_ids)
# vectors = np.array([labevent_vectors[code] for code in labevent_ids])
# Out:
# ['50971', '50983', '50902', '50912', '51006', '50882', '50868', '50931', '51221', '51222', '51265', '51301', '51249', '51248', '51279', '51250', '51277', '50960', '50970', '50893', '50934', '50947', '51678', '52172', '51275', '51237', '51274', '50820', '50821', '50802', '50804', '50818', '50878', '50861', '50863', '50885', '50813', '51256', '51244', '51200', '51254', '51146', '51491', '51498', '50862', '50954', '50911', '50910', '51133', '52075', '52073', '52074', '52069', '51003', '50808', '51493', '52135', '51476', '51516', '50822', '51492', '50809', '51009', '50817', '50825', '50993', '50824', '50956', '51082', '51144', '51482', '51100', '50816', '51251', '51255', '51143', '51093', '50952', '50924', '50967', '50810', '50811', '50953', '50998', '51010', '50819', '50806', '51214', '50826', '50964', '51514', '51097', '51104', '50852', '50986', '50963', '51078', '51000', '51613', '51478', '51283', '50867', '50935', '50907', '50889', '51257', '50904', '50903', '50905', '51484', '50908', '51007', '51282', '50925', '50909', '51008', '50884', '50995', '50976', '50883', '51102', '50803', '50994', '50815', '50917', '51737', '50823', '50801', '51288', '51099', '52281', '52264', '52272', '52286', '52285', '52004', '52005', '52006', '52008', '52010', '52007', '52009', '51351', '51355', '51360', '51363', '51479', '51501', '50853', '51362', '51018', '51657', '50930', '51802', '51790', '50914', '51014', '50965', '51001', '50866', '51659', '51148', '51663', '51734', '51736', '51735', '50961', '51455', '51450', '51446', '51054', '51059', '50949', '50927', '50950', '52391', '51457', '51053', '50951', '50915', '50978', '50831', '51228', '51564', '50957', '51447', '51051', '50929', '52024', '51218', '50856', '51046', '51269', '51448', '51379', '51382', '51375', '50906', '52312', '51259', '50974', '51431', '51436', '51427', '51352', '51383', '51626', '51627', '51625', '51095', '51658', '51077', '50900', '51120', '51125', '51116', '51094', '51108', '51087', '51127', '51196', '51297', '51453', '52065', '50805', '51347', '51117', '51070', '52266', '50997', '51069', '51428', '51444', '51300', '51180', '51131', '51245', '51181', '51194', '51176', '51132', '51130', '51749', '50814', '50980', '51067', '50973', '52769', '51921', '50849', '51376', '50996', '51229', '51118', '51047', '51088', '50890', '50922', '50891', '50899', '51105', '51002', '51795', '50842', '50835', '51284', '51005', '50896', '50895', '52256', '50864', '50843', '51060', '51419', '51434', '50881', '51052', '51463', '51662', '52278', '51732', '50969', '50968', '50966', '51358', '51497', '51343', '52223', '51123', '50836', '52369', '51471', '51445', '51442', '50892', '50841', '50945', '51068', '51101', '51080', '51106', '51429', '51081', '51109', '51263', '51438', '51026', '51348', '51661', '51454', '51345', '50992', '50838', '51043', '50988', '51458', '50991', '51660', '52221', '51034', '52358', '51617', '51138', '51035', '51615', '51139', '51587', '51114', '51028', '51344', '51422', '51276', '51076', '51140', '51733', '51015', '51689', '51616', '51025', '51368', '51128', '51206', '51598', '51440', '51441', '51489', '51369', '51289', '51507', '51298', '51032', '51024', '50982', '52225', '51022', '52276', '52279', '50981', '50926', '51768', '51271', '51226', '51651', '51227', '51224', '52018', '51439', '51299', '51023', '51112', '50898', '50865', '50958', '51223', '51273', '51517', '51567', '51175', '51174', '50894', '51763', '51762', '51353', '51066', '51225', '51208', '51124', '51036', '51185', '51186', '51110', '52301', '51202', '51652', '52109', '51065', '51494', '50946', '51386', '51387', '52179', '51357', '51205', '51063', '51381', '51384', '51764', '51111', '51204', '51241', '51654', '51515', '51435', '50869', '51073', '51072', '51367', '51232', '51064', '50877', '51044', '51233', '51062', '52108', '52107', '51452', '51377', '52132']

# %%
from transformers import BertModel, BertTokenizer
import torch
import numpy as np

model_name = "bert-base-uncased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

def get_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    outputs = model(**inputs)
    embeddings = outputs.last_hidden_state[:, 0, :].detach().numpy()
    return embeddings

labevent_ids = list(set([code for seq in patients_itemid_seqs for code in seq]))
vectors = np.array([get_embedding(str(code)).squeeze() for code in labevent_ids])

print(vectors.shape)
# Out:
# (502, 768)

# %% [markdown]
# Apply PCA to reform the dimensions

# %%
pca = PCA(n_components=20)
vectors_pca = pca.fit_transform(vectors)

# %%
print(len(vectors_pca))
print(vectors_pca)
# Out:
# 502
# [[ 1.6219109   0.14971976  0.695458   ... -0.22072573 -0.22783728
#    0.07428312]
#  [ 1.1353965   0.8450356  -0.4782573  ...  0.4748825  -0.30627847
#    0.158902  ]
#  [ 0.8180506   0.0953743  -0.2697036  ...  0.48568833 -0.3545477
#    0.4270067 ]
#  ...
#  [ 0.01391686 -0.64352304 -1.1403724  ...  0.14527725 -0.13329057
#    0.02843399]
#  [ 0.09696224  1.5133487   0.5560402  ...  0.00401746  0.04017084
#   -0.2679313 ]
#  [ 2.422658   -0.43818244 -1.7799984  ... -0.58017343  0.15856272
#    0.359783  ]]

# %%
# check cumulative_variance_ratio
explained_variance_ratio = pca.explained_variance_ratio_

print("Explained Variance Ratio per Principal Component:")
print(explained_variance_ratio)


cumulative_variance_ratio = np.cumsum(explained_variance_ratio)
print("Cumulative Explained Variance Ratio:")
print(cumulative_variance_ratio)
# Out:
# Explained Variance Ratio per Principal Component:
# [0.20478845 0.13936073 0.07793356 0.05659496 0.04853039 0.04107222
#  0.03327609 0.02964417 0.02461977 0.02168976 0.02054347 0.01855835
#  0.01683578 0.01527007 0.0137976  0.01215549 0.01138141 0.00964511
#  0.00910132 0.00816308]
# Cumulative Explained Variance Ratio:
# [0.20478845 0.34414917 0.42208272 0.4786777  0.5272081  0.5682803
#  0.60155636 0.63120055 0.6558203  0.6775101  0.69805354 0.71661186
#  0.7334477  0.7487177  0.7625153  0.7746708  0.78605217 0.7956973
#  0.8047986  0.8129617 ]

# %% [markdown]
# # **k-means for the embeded itemids**

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
import numpy as np
import matplotlib.pyplot as plt

eps_values = np.arange(0.1, 2.0, 0.2)
min_samples_values = range(3, 18)

dbscan_silhouette_scores = []

for eps in eps_values:
    for min_samples in min_samples_values:
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        cluster_labels = dbscan.fit_predict(vectors_pca)

        if len(set(cluster_labels)) > 1 and len(set(cluster_labels) - {-1}) > 1:
            silhouette_avg = silhouette_score(vectors_pca, cluster_labels)
        else:
            silhouette_avg = -1

        dbscan_silhouette_scores.append({
            'eps': eps,
            'min_samples': min_samples,
            'silhouette_score': silhouette_avg
        })
        print(f"eps = {eps}, min_samples = {min_samples}, Silhouette Score: {silhouette_avg}")

import pandas as pd
df_silhouette = pd.DataFrame(dbscan_silhouette_scores)

plt.figure(figsize=(10, 6))

# plot silhouette scores
for min_samples in min_samples_values:
    subset = df_silhouette[df_silhouette['min_samples'] == min_samples]
    plt.plot(subset['eps'], subset['silhouette_score'], marker='o', label=f'min_samples={min_samples}')

plt.title('Silhouette Score for different eps and min_samples values in DBSCAN')
plt.xlabel('eps')
plt.ylabel('Silhouette Score')
plt.legend(title='min_samples')
plt.grid(True)
plt.show()
# Out:
# eps = 0.1, min_samples = 3, Silhouette Score: -1
# eps = 0.1, min_samples = 4, Silhouette Score: -1
# eps = 0.1, min_samples = 5, Silhouette Score: -1
# eps = 0.1, min_samples = 6, Silhouette Score: -1
# eps = 0.1, min_samples = 7, Silhouette Score: -1
# eps = 0.1, min_samples = 8, Silhouette Score: -1
# eps = 0.1, min_samples = 9, Silhouette Score: -1
# eps = 0.1, min_samples = 10, Silhouette Score: -1
# eps = 0.1, min_samples = 11, Silhouette Score: -1
# eps = 0.1, min_samples = 12, Silhouette Score: -1
# eps = 0.1, min_samples = 13, Silhouette Score: -1
# eps = 0.1, min_samples = 14, Silhouette Score: -1
# eps = 0.1, min_samples = 15, Silhouette Score: -1
# eps = 0.1, min_samples = 16, Silhouette Score: -1
# eps = 0.1, min_samples = 17, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 3, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 4, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 5, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 6, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 7, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 8, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 9, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 10, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 11, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 12, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 13, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 14, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 15, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 16, Silhouette Score: -1
# eps = 0.30000000000000004, min_samples = 17, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 3, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 4, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 5, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 6, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 7, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 8, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 9, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 10, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 11, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 12, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 13, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 14, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 15, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 16, Silhouette Score: -1
# eps = 0.5000000000000001, min_samples = 17, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 3, Silhouette Score: -0.2007189691066742
# eps = 0.7000000000000001, min_samples = 4, Silhouette Score: -0.17297883331775665
# eps = 0.7000000000000001, min_samples = 5, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 6, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 7, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 8, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 9, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 10, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 11, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 12, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 13, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 14, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 15, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 16, Silhouette Score: -1
# eps = 0.7000000000000001, min_samples = 17, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 3, Silhouette Score: -0.16678878664970398
# eps = 0.9000000000000001, min_samples = 4, Silhouette Score: -0.1868658810853958
# eps = 0.9000000000000001, min_samples = 5, Silhouette Score: -0.17857962846755981
# eps = 0.9000000000000001, min_samples = 6, Silhouette Score: -0.12451230734586716
# eps = 0.9000000000000001, min_samples = 7, Silhouette Score: -0.1272667497396469
# eps = 0.9000000000000001, min_samples = 8, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 9, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 10, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 11, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 12, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 13, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 14, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 15, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 16, Silhouette Score: -1
# eps = 0.9000000000000001, min_samples = 17, Silhouette Score: -1
# eps = 1.1000000000000003, min_samples = 3, Silhouette Score: -0.03915137052536011
# eps = 1.1000000000000003, min_samples = 4, Silhouette Score: -0.055859196931123734
# eps = 1.1000000000000003, min_samples = 5, Silhouette Score: -0.04743705689907074
# eps = 1.1000000000000003, min_samples = 6, Silhouette Score: -0.07652701437473297
# eps = 1.1000000000000003, min_samples = 7, Silhouette Score: -0.11290384083986282
# eps = 1.1000000000000003, min_samples = 8, Silhouette Score: -0.11718698590993881
# eps = 1.1000000000000003, min_samples = 9, Silhouette Score: -0.12072103470563889
# eps = 1.1000000000000003, min_samples = 10, Silhouette Score: -0.12072103470563889
# eps = 1.1000000000000003, min_samples = 11, Silhouette Score: -0.12366336584091187
# eps = 1.1000000000000003, min_samples = 12, Silhouette Score: -0.10209082812070847
# eps = 1.1000000000000003, min_samples = 13, Silhouette Score: -0.10748688876628876
# eps = 1.1000000000000003, min_samples = 14, Silhouette Score: -1
# eps = 1.1000000000000003, min_samples = 15, Silhouette Score: -1
# eps = 1.1000000000000003, min_samples = 16, Silhouette Score: -1
# eps = 1.1000000000000003, min_samples = 17, Silhouette Score: -1
# eps = 1.3000000000000003, min_samples = 3, Silhouette Score: 0.03684740886092186
# eps = 1.3000000000000003, min_samples = 4, Silhouette Score: -0.0038672827649861574
# eps = 1.3000000000000003, min_samples = 5, Silhouette Score: 0.0025683969724923372
# eps = 1.3000000000000003, min_samples = 6, Silhouette Score: 0.01278819888830185
# eps = 1.3000000000000003, min_samples = 7, Silhouette Score: -0.02371298521757126
# eps = 1.3000000000000003, min_samples = 8, Silhouette Score: -0.040322769433259964
# eps = 1.3000000000000003, min_samples = 9, Silhouette Score: -0.04605952277779579
# eps = 1.3000000000000003, min_samples = 10, Silhouette Score: -0.07089482992887497
# eps = 1.3000000000000003, min_samples = 11, Silhouette Score: -0.07967056334018707
# eps = 1.3000000000000003, min_samples = 12, Silhouette Score: -0.07520730048418045
# eps = 1.3000000000000003, min_samples = 13, Silhouette Score: -0.07708027213811874
# eps = 1.3000000000000003, min_samples = 14, Silhouette Score: -0.0933697447180748
# eps = 1.3000000000000003, min_samples = 15, Silhouette Score: -0.0933697447180748
# eps = 1.3000000000000003, min_samples = 16, Silhouette Score: -1
# eps = 1.3000000000000003, min_samples = 17, Silhouette Score: -1
# eps = 1.5000000000000004, min_samples = 3, Silhouette Score: 0.10079803317785263
# eps = 1.5000000000000004, min_samples = 4, Silhouette Score: 0.06980933994054794
# eps = 1.5000000000000004, min_samples = 5, Silhouette Score: 0.04766141250729561
# eps = 1.5000000000000004, min_samples = 6, Silhouette Score: 0.03559815511107445
# eps = 1.5000000000000004, min_samples = 7, Silhouette Score: 0.024980628862977028
# eps = 1.5000000000000004, min_samples = 8, Silhouette Score: 0.009669783525168896
# eps = 1.5000000000000004, min_samples = 9, Silhouette Score: 0.0061803641729056835
# eps = 1.5000000000000004, min_samples = 10, Silhouette Score: -0.00635497085750103
# eps = 1.5000000000000004, min_samples = 11, Silhouette Score: -0.019104616716504097
# eps = 1.5000000000000004, min_samples = 12, Silhouette Score: -0.03962892293930054
# eps = 1.5000000000000004, min_samples = 13, Silhouette Score: -0.0502978190779686
# eps = 1.5000000000000004, min_samples = 14, Silhouette Score: -0.061584364622831345
# eps = 1.5000000000000004, min_samples = 15, Silhouette Score: -0.06021846830844879
# eps = 1.5000000000000004, min_samples = 16, Silhouette Score: -0.0767575278878212
# eps = 1.5000000000000004, min_samples = 17, Silhouette Score: -0.07465356588363647
# eps = 1.7000000000000004, min_samples = 3, Silhouette Score: 0.1787160485982895
# eps = 1.7000000000000004, min_samples = 4, Silhouette Score: 0.14212486147880554
# eps = 1.7000000000000004, min_samples = 5, Silhouette Score: 0.10547409951686859
# eps = 1.7000000000000004, min_samples = 6, Silhouette Score: 0.11238816380500793
# eps = 1.7000000000000004, min_samples = 7, Silhouette Score: 0.0832023173570633
# eps = 1.7000000000000004, min_samples = 8, Silhouette Score: 0.06229748576879501
# eps = 1.7000000000000004, min_samples = 9, Silhouette Score: 0.06890835613012314
# eps = 1.7000000000000004, min_samples = 10, Silhouette Score: 0.05504731088876724
# eps = 1.7000000000000004, min_samples = 11, Silhouette Score: 0.05412003770470619
# eps = 1.7000000000000004, min_samples = 12, Silhouette Score: 0.04793034866452217
# eps = 1.7000000000000004, min_samples = 13, Silhouette Score: 0.032867126166820526
# eps = 1.7000000000000004, min_samples = 14, Silhouette Score: 0.009208335541188717
# eps = 1.7000000000000004, min_samples = 15, Silhouette Score: -0.03740720450878143
# eps = 1.7000000000000004, min_samples = 16, Silhouette Score: -0.038923487067222595
# eps = 1.7000000000000004, min_samples = 17, Silhouette Score: -0.041210174560546875
# eps = 1.9000000000000004, min_samples = 3, Silhouette Score: 0.16976067423820496
# eps = 1.9000000000000004, min_samples = 4, Silhouette Score: 0.16510625183582306
# eps = 1.9000000000000004, min_samples = 5, Silhouette Score: 0.16842970252037048
# eps = 1.9000000000000004, min_samples = 6, Silhouette Score: 0.1524817794561386
# eps = 1.9000000000000004, min_samples = 7, Silhouette Score: 0.13313418626785278
# eps = 1.9000000000000004, min_samples = 8, Silhouette Score: 0.12993136048316956
# eps = 1.9000000000000004, min_samples = 9, Silhouette Score: 0.1160326823592186
# eps = 1.9000000000000004, min_samples = 10, Silhouette Score: 0.10737992823123932
# eps = 1.9000000000000004, min_samples = 11, Silhouette Score: 0.10190986096858978
# eps = 1.9000000000000004, min_samples = 12, Silhouette Score: 0.09699968993663788
# eps = 1.9000000000000004, min_samples = 13, Silhouette Score: 0.08891581743955612
# eps = 1.9000000000000004, min_samples = 14, Silhouette Score: 0.08706025779247284
# eps = 1.9000000000000004, min_samples = 15, Silhouette Score: 0.0860297679901123
# eps = 1.9000000000000004, min_samples = 16, Silhouette Score: 0.023983962833881378
# eps = 1.9000000000000004, min_samples = 17, Silhouette Score: 0.01781587302684784

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import plotly.graph_objs as go
from plotly.offline import iplot
import pandas as pd


n_clusters = 24
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(vectors_pca)

# t-SNE to visualize the clusters
tsne = TSNE(n_components=3, random_state=42)
vectors_tsne = tsne.fit_transform(vectors_pca)

query = """
    SELECT
        itemid,
        label
    FROM
        `physionet-data.mimiciv_hosp.d_labitems`
"""

df_labitems = bf.read_gbq(query).to_pandas()
print(len(df_labitems))
print(df_labitems.head(1))

itemid_to_label = dict(zip(df_labitems['itemid'].astype(str), df_labitems['label']))

itemid_label_list = [f"{itemid}: {itemid_to_label.get(str(itemid), 'Unknown Label')}" for itemid in labevent_ids]

trace = go.Scatter3d(
    x=vectors_tsne[:, 0],
    y=vectors_tsne[:, 1],
    z=vectors_tsne[:, 2],
    mode='markers',
    marker=dict(
        size=3,
        color=cluster_labels,
        colorscale='Viridis',
        opacity=0.8
    ),
    text=itemid_label_list
)

data = [trace]

layout = go.Layout(
    title='3D t-SNE Visualization of Lab Event IDs with KMeans Clusters',
    scene=dict(
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        zaxis=dict(title='Dimension 3')
    )
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)

cluster_itemids = {i: [] for i in range(n_clusters)}  # Initialize a dictionary for each cluster

for idx, label in enumerate(cluster_labels):
    cluster_itemids[label].append(labevent_ids[idx])

# for cluster, itemids in cluster_itemids.items():
#     print(f"Cluster {cluster}: {len(itemids)} items")
#     print(itemids)
# Out:
# Query job 457e4394-962b-4620-b3e5-bf6d11e1b3f4 is DONE. 36.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:457e4394-962b-4620-b3e5-bf6d11e1b3f4&page=queryresults">Open Job</a>
# Query job 26a6e679-49f0-4e39-8783-07543e547aae is DONE. 36.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:26a6e679-49f0-4e39-8783-07543e547aae&page=queryresults">Open Job</a>
# 1622
#    itemid  label
# 0   52397  FL2-D
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="332dbe49-1b03-43b7-9dae-089d58e320b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("332dbe49-1b03-43b7-9dae-089d58e320b2")) {                    Plotly.newPlot(                        "332dbe49-1b03-43b7-9dae-089d58e320b2",                        [{"marker":{"color":[20,12,12,0,13,8,0,1,19,13,21,0,16,18,2,21,3,3,4,19,23,18,5,15,6,1,15,15,0,2,4,23,4,19,18,17,1,14,0,5,19,13,14,16,16,3,20,21,4,4,9,9,1,22,16,9,6,17,22,6,2,4,8,17,15,14,7,12,4,21,0,16,11,23,15,18,23,3,22,3,1,0,13,5,0,18,4,6,16,19,0,7,18,9,3,4,3,0,2,19,11,18,11,15,12,9,23,1,5,21,1,0,11,11,17,17,2,4,9,15,4,12,22,16,16,15,14,17,17,13,20,12,2,15,2,19,4,2,12,23,8,17,3,16,16,6,20,4,10,1,1,12,0,15,10,13,13,13,11,10,10,11,19,17,16,20,17,4,6,3,18,0,9,9,5,12,17,3,22,9,10,11,15,17,23,12,20,10,0,6,4,15,3,20,22,13,22,3,2,6,3,6,6,20,6,9,2,17,17,12,2,18,2,7,22,10,2,13,23,9,4,4,5,7,18,5,2,19,17,7,14,15,3,15,4,1,10,2,0,11,23,9,1,15,3,9,9,15,6,3,1,10,12,22,13,4,14,8,13,23,4,17,18,9,6,13,18,12,13,6,1,22,13,4,1,6,20,6,20,3,19,2,15,15,19,23,11,14,17,22,9,11,1,18,13,8,0,20,18,2,10,11,0,2,23,0,20,22,14,9,7,5,19,6,16,1,11,10,1,9,16,18,14,10,14,2,18,1,16,14,12,4,14,9,19,12,11,7,11,9,6,23,5,9,18,23,0,9,6,4,3,23,13,5,18,0,18,13,11,18,6,3,12,15,22,1,4,15,22,10,3,11,19,2,3,18,13,1,23,2,18,0,22,9,14,13,4,2,20,4,1,9,0,18,11,4,14,23,4,2,17,9,20,9,3,3,5,13,9,12,0,20,16,13,0,18,2,10,2,9,9,0,19,14,18,10,8,15,12,22,5,21,20,14,18,22,22,13,18,10,17,19,15,8,3,10,14,3,18,19,19,18,2,5,16,18,6,1,9,3,2,22,11,19,21,12,11,2,3,3,0,13,7,4,3,12,1,9,1,6,9,18,9,9,6,15,17,11,6,3,4,5,6,22,5,20,6,11,4,6,5,18],"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.8,"size":3},"mode":"markers","text":["51735: STX4","50818: pCO2","50813: Lactate","51297: Thrombin","50853: 25-OH Vitamin D","51259: Other Cells","51269: Promyelocytes","51921: proBNP, Pleural","50957: Lithium","51063: Osmolality, Stool","51265: Platelet Count","51206: Factor VIII","51006: Urea Nitrogen","51659: HPE3","51492: Protein","51246: Macrocytes","51376: Macrophage","51516: WBC","51667: H. pylori IgG Ab Value","50870: Anti-Gliadin Antibody, IgA","51070: Albumin\u002fCreatinine, Urine","51689: Lyme G and M Value","52132: HIT-Ab Numerical Result","51095: Phosphate, Urine","51118: Mesothelial Cell","50945: Homocysteine","51345: Unknown Label","51125: Polys","51273: Protein S, Functional","50902: Chloride","50967: Phenytoin","51047: Amylase, Pleural","52177: SCT - Confirmation","50946: Human Chorionic Gonadotropin","51109: Urine Volume, Total","51245: Lymphocytes, Percent","50924: Ferritin","51360: Unknown Label","51289: Serum Viscosity","51054: Lactate Dehydrogenase, Pleural","51749: Treponema pallidum (syphilis) value","51353: Unknown Label","51110: Atypical Lymphocytes","51011: Unknown Label","51020: Amylase, Joint Fluid","50906: Cholesterol, LDL, Measured","51726: Rubeola IgG Ab Value","51248: MCH","51127: RBC, Ascites","51447: Macrophages","50864: Alpha-Fetoprotein","52264: Lymphs","50841: Creatinine, Ascites","50971: Potassium","51014: Unknown Label","51494: RBC Casts","51148: Blasts","51218: Granulocyte Count","50973: Prolactin","51128: Unknown Label","51452: NRBC","51767: EE5","51280: Reptilase Time","51222: Hemoglobin","51105: Uric Acid, Urine","51440: Atypical Lymphocytes","50964: Osmolality, Measured","51616: Epstein-Barr Virus IgG Ab Value","51457: RBC, Pleural","51244: Lymphocytes","51274: PT","51001: Triiodothyronine (T3)","51381: Other","52075: Absolute Neutrophil Count","51115: Hema ...

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import plotly.graph_objs as go
from plotly.offline import iplot
import pandas as pd


pca = PCA(n_components=20)
vectors_pca = pca.fit_transform(vectors)  # Perform PCA first

tsne = TSNE(n_components=3, random_state=42)
vectors_tsne = tsne.fit_transform(vectors_pca)  # Use PCA-reduced data for t-SNE

n_clusters = 24  # Adjust the number of clusters as needed
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(vectors_tsne)  # Perform clustering on t-SNE-reduced data

query = """
    SELECT
        itemid,
        label
    FROM
        `physionet-data.mimiciv_hosp.d_labitems`
"""

df_labitems = bf.read_gbq(query).to_pandas()
print(len(df_labitems))
print(df_labitems.head(1))

itemid_to_label = dict(zip(df_labitems['itemid'].astype(str), df_labitems['label']))

itemid_label_list = [f"{itemid}: {itemid_to_label.get(str(itemid), 'Unknown Label')}" for itemid in labevent_ids]

trace = go.Scatter3d(
    x=vectors_tsne[:, 0],
    y=vectors_tsne[:, 1],
    z=vectors_tsne[:, 2],
    mode='markers',
    marker=dict(
        size=3,
        color=cluster_labels,
        colorscale='Viridis',
        opacity=0.9
    ),
    text=itemid_label_list
)

data = [trace]

layout = go.Layout(
    title='3D t-SNE Visualization of Lab Event IDs with KMeans Clusters',
    scene=dict(
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        zaxis=dict(title='Dimension 3')
    )
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)

cluster_itemids = {i: [] for i in range(n_clusters)}

for idx, label in enumerate(cluster_labels):
    cluster_itemids[label].append(labevent_ids[idx])

# for cluster, itemids in cluster_itemids.items():
#     print(f"Cluster {cluster}: {len(itemids)} items")
#     print(itemids)
# Out:
# Query job 5f9852aa-ec81-4e7e-9066-fe655604d476 is DONE. 36.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:5f9852aa-ec81-4e7e-9066-fe655604d476&page=queryresults">Open Job</a>
# Query job e472e824-d08f-4eef-bcb9-d55c0cd04152 is DONE. 36.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:e472e824-d08f-4eef-bcb9-d55c0cd04152&page=queryresults">Open Job</a>
# 1622
#    itemid  label
# 0   52397  FL2-D
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0d3f8e58-d841-400a-a5f1-14162833ff0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d3f8e58-d841-400a-a5f1-14162833ff0e")) {                    Plotly.newPlot(                        "0d3f8e58-d841-400a-a5f1-14162833ff0e",                        [{"marker":{"color":[13,3,3,0,2,10,0,19,7,2,10,0,8,17,20,10,1,1,21,7,16,15,5,14,18,19,14,14,23,9,4,16,4,7,17,10,19,11,0,16,7,22,11,5,5,1,19,10,21,21,6,6,19,12,5,6,18,10,2,18,20,4,10,10,14,11,7,3,21,10,23,5,12,16,14,17,16,1,12,1,19,23,22,5,23,15,4,18,5,7,23,7,17,6,1,21,1,23,20,13,12,17,12,14,3,6,16,7,5,10,13,23,12,12,10,10,20,21,6,14,21,3,12,5,4,14,11,10,10,22,13,3,20,14,20,7,21,9,3,3,10,10,1,5,16,18,13,21,15,13,13,3,0,14,15,22,2,22,12,15,15,12,13,10,5,19,10,4,18,8,17,23,6,6,16,3,10,1,9,6,15,12,14,10,16,3,13,8,0,18,21,14,1,19,9,22,9,1,20,18,1,18,18,19,18,6,9,10,10,3,20,8,20,7,2,15,20,2,16,6,21,4,16,7,8,16,9,7,10,7,11,14,8,14,21,13,15,20,0,12,16,6,13,14,1,6,6,14,18,1,13,15,3,12,2,21,11,10,2,16,21,10,17,6,18,22,15,3,22,18,19,9,22,21,3,8,13,18,19,1,7,20,14,14,7,16,12,11,10,9,6,12,13,17,22,10,0,19,17,20,8,12,23,9,16,0,13,12,11,6,7,16,7,18,5,19,12,8,13,6,5,17,11,15,11,20,17,13,5,11,3,4,11,6,7,3,12,7,12,6,18,16,16,6,17,16,23,6,18,21,1,16,2,5,8,0,17,22,12,17,18,1,3,14,2,13,4,14,2,4,1,12,7,9,1,17,2,19,16,20,17,23,9,6,11,2,4,20,19,21,19,6,23,17,12,21,11,16,21,20,10,6,7,6,1,1,16,22,6,3,23,19,14,22,23,17,9,15,20,6,6,23,7,11,17,8,10,14,3,12,16,10,7,11,8,9,2,22,17,15,10,7,14,10,1,8,11,1,17,7,13,8,20,5,5,17,18,3,6,1,9,2,12,7,10,3,12,20,1,1,23,2,7,4,1,3,13,6,13,18,6,17,6,6,18,14,10,12,18,1,4,16,18,9,16,13,18,12,21,18,16,15],"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.9,"size":3},"mode":"markers","text":["51735: STX4","50818: pCO2","50813: Lactate","51297: Thrombin","50853: 25-OH Vitamin D","51259: Other Cells","51269: Promyelocytes","51921: proBNP, Pleural","50957: Lithium","51063: Osmolality, Stool","51265: Platelet Count","51206: Factor VIII","51006: Urea Nitrogen","51659: HPE3","51492: Protein","51246: Macrocytes","51376: Macrophage","51516: WBC","51667: H. pylori IgG Ab Value","50870: Anti-Gliadin Antibody, IgA","51070: Albumin\u002fCreatinine, Urine","51689: Lyme G and M Value","52132: HIT-Ab Numerical Result","51095: Phosphate, Urine","51118: Mesothelial Cell","50945: Homocysteine","51345: Unknown Label","51125: Polys","51273: Protein S, Functional","50902: Chloride","50967: Phenytoin","51047: Amylase, Pleural","52177: SCT - Confirmation","50946: Human Chorionic Gonadotropin","51109: Urine Volume, Total","51245: Lymphocytes, Percent","50924: Ferritin","51360: Unknown Label","51289: Serum Viscosity","51054: Lactate Dehydrogenase, Pleural","51749: Treponema pallidum (syphilis) value","51353: Unknown Label","51110: Atypical Lymphocytes","51011: Unknown Label","51020: Amylase, Joint Fluid","50906: Cholesterol, LDL, Measured","51726: Rubeola IgG Ab Value","51248: MCH","51127: RBC, Ascites","51447: Macrophages","50864: Alpha-Fetoprotein","52264: Lymphs","50841: Creatinine, Ascites","50971: Potassium","51014: Unknown Label","51494: RBC Casts","51148: Blasts","51218: Granulocyte Count","50973: Prolactin","51128: Unknown Label","51452: NRBC","51767: EE5","51280: Reptilase Time","51222: Hemoglobin","51105: Uric Acid, Urine","51440: Atypical Lymphocytes","50964: Osmolality, Measured","51616: Epstein-Barr Virus IgG Ab Value","51457: RBC, Pleural","51244: Lymphocytes","51274: PT","51001: Triiodothyronine (T3)","51381: Other","52075: Absolu ...

# %%
from sklearn.metrics import silhouette_score
inertia = kmeans.inertia_
print(f"Inertia: {inertia}")

silhouette_avg = silhouette_score(vectors_pca, cluster_labels)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Inertia: 1493.520751953125
# Silhouette Score: 0.2511022388935089

# %%
merged_df_sorted.head(5)
# Out:
#     itemid  count          label  fluid   category
# 70   50912   3729     Creatinine  Blood  Chemistry
# 130  51006   3728  Urea Nitrogen  Blood  Chemistry
# 107  50971   3727      Potassium  Blood  Chemistry
# 60   50902   3722       Chloride  Blood  Chemistry
# 46   50882   3722    Bicarbonate  Blood  Chemistry

# %%
merged_df_sorted.dtypes
# Out:
# itemid               object
# count                 int64
# label       string[pyarrow]
# fluid       string[pyarrow]
# category    string[pyarrow]
# dtype: object

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import plotly.graph_objs as go
from plotly.offline import iplot
import pandas as pd


pca = PCA(n_components=20)
vectors_pca = pca.fit_transform(vectors)  # Perform PCA first

tsne = TSNE(n_components=3, random_state=42)
vectors_tsne = tsne.fit_transform(vectors_pca)  # Use PCA-reduced data for t-SNE

n_clusters = 24  # Adjust the number of clusters as needed
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(vectors_tsne)  # Perform clustering on t-SNE-reduced data

query = """
    SELECT
        itemid,
        label
    FROM
        `physionet-data.mimiciv_hosp.d_labitems`
"""

df_labitems = bf.read_gbq(query).to_pandas()
print(len(df_labitems))
print(df_labitems.head(1))

itemid_to_label = dict(zip(df_labitems['itemid'].astype(str), df_labitems['label']))

itemid_label_list = [f"{itemid}: {itemid_to_label.get(str(itemid), 'Unknown Label')}" for itemid in labevent_ids]
# Out:
# Query job 850fa8e9-3a32-4858-8c95-8933d841ab28 is DONE. 36.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:850fa8e9-3a32-4858-8c95-8933d841ab28&page=queryresults">Open Job</a>
# Query job 9a33a8ac-55e2-4fb8-94f5-6a8802b4220b is DONE. 36.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:9a33a8ac-55e2-4fb8-94f5-6a8802b4220b&page=queryresults">Open Job</a>
# 1622
#    itemid  label
# 0   52397  FL2-D

# %%
trace = go.Scatter3d(
    x=vectors_tsne[:, 0],
    y=vectors_tsne[:, 1],
    z=vectors_tsne[:, 2],
    mode='markers',
    marker=dict(
        size=3,
        color=cluster_labels,
        colorscale='Viridis',
        opacity=0.9
    ),
    text=itemid_label_list
)

# add spheres for each cluster
def create_sphere(x, y, z, radius, resolution=20):
    """Generate the surface coordinates for a sphere centered at (x, y, z)."""
    phi, theta = np.mgrid[0:2 * np.pi:resolution*2j, 0:np.pi:resolution*1j]
    X = radius * np.sin(theta) * np.cos(phi)
    Y = radius * np.sin(theta) * np.sin(phi)
    Z = radius * np.cos(theta)
    return X + x, Y + y, Z + z

sphere_traces = []
for i in range(n_clusters):
    cluster_points = vectors_tsne[cluster_labels == i]
    center = cluster_points.mean(axis=0)
    radius = np.linalg.norm(cluster_points - center, axis=1).mean() * 1.5

    X, Y, Z = create_sphere(center[0], center[1], center[2], radius, resolution=30)

    sphere_trace = go.Surface(
        x=X, y=Y, z=Z,
        opacity=0.15,
        colorscale='Blues',
        showscale=False,
        hoverinfo='skip'
    )
    sphere_traces.append(sphere_trace)

data = sphere_traces + [trace]

layout = go.Layout(
    title='3D t-SNE Visualization of Lab Event IDs with KMeans Clusters',
    scene=dict(
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        zaxis=dict(title='Dimension 3')
    ),
    hovermode='closest'
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)

cluster_itemids = {i: [] for i in range(n_clusters)}

for idx, label in enumerate(cluster_labels):
    cluster_itemids[label].append(labevent_ids[idx])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fac9ee51-4f73-4df5-b48c-e46831c09594" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fac9ee51-4f73-4df5-b48c-e46831c09594")) {                    Plotly.newPlot(                        "fac9ee51-4f73-4df5-b48c-e46831c09594",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"hoverinfo":"skip","opacity":0.15,"showscale":false,"x":[[-9.47372055053711,-9.179027796160709,-8.887790044889218,-8.603421793075077,-8.329256998470438,-8.068509992620774,-7.824237795766415,-7.5993042760752765,-7.396346573407061,-7.217744181259554,-7.065591049382961,-6.941671034133602,-6.847436984389123,-6.7839937082237665,-6.752085020043829,-6.752085020043829,-6.7839937082237665,-6.847436984389123,-6.941671034133602,-7.065591049382961,-7.217744181259554,-7.396346573407061,-7.5993042760752765,-7.824237795766415,-8.068509992620774,-8.329256998470438,-8.603421793075078,-8.887790044889217,-9.179027796160709,-9.47372055053711],[-9.47372055053711,-9.180697289490876,-8.891109458266689,-8.608352209412969,-8.335740613145111,-8.076470791178195,-7.833582445122124,-7.609923218759473,-7.408115312025765,-7.23052473811272,-7.079233584126863,-6.956015600521854,-6.862315405496185,-6.799231548165628,-6.767503629079263,-6.767503629079263,-6.799231548165628,-6.862315405496186,-6.956015600521854,-7.079233584126863,-7.23052473811272,-7.408115312025765,-7.609923218759473,-7.833582445122124,-8.076470791178195,-8.335740613145111,-8.60835220941297,-8.891109458266687,-9.180697289490876,-9.47372055053711],[-9.47372055053711,-9.185686853454852,-8.901030088119164,-8.623087594839442,-8.355117995224147,-8.100262987821827,-7.86151051457812,-7.641659729948337,-7.443288183370776,-7.268721599856223,-7.120006612988638,-6.998886770017632,-6.906782090361112,-6.844772417175941,-6.813584757184229,-6.813584757184229,-6.844772417175941,-6.906782090361112,-6.998886770017632,-7.120006612988638,-7.268721599856223,-7.443288183370776,-7.641659729948337,-7.86151051457812,-8.100262987821829,-8.355117995224148,-8.623087594839442,-8.901030088119162,-9.185686853454852,-9.47372055053711],[-9.47372055053711,-9.193939954299195,-8.917439529746332,-8.647460991549652,-8.387169591225781,-8.13961700745682,-7.907705567947974,-7.694154222288832,-7.501466664755391,-7.331901980783816,-7.187448161259205,-7.069798795140098,-6.980333213676399,-6.92010031901161,-6.889806286764214,-6.889806286764214,-6.92010031901161,-6.9803332136764,-7.069798795140098,-7.187448161259205,-7.331901980783816,-7.501466664755391,-7.694154222288832,-7.907705567947975,-8.13961700745682,-8.387169591225781,-8.647460991549654,-8.91743952974633,-9.193939954299195,-9.47372055053711],[-9.47372055053711,-9.205363081093568,-8.940151857617677,-8.681196239219759,-8.431532243760149,-8.194086953315642,-7.971644196818401,-7.766811912207006,-7.58199157073858,-7.41935002193399,-7.280794089248387,-7.167948214309609,-7.082135411825346,-7.024361758445335,-6.995304597432499,-6.995304597432499,-7.024361758445335,-7.082135411825346,-7.167948214309609,-7.280794089248387,-7.41935002193399,-7.58199157073858,-7.766811912207006,-7.971644196818401,-8.194086953315642,-8.431532243760149,-8.681196239219759,-8.940151857617677,-9.205363081093568,-9.47372055053711],[-9.47372055053711,-9.219826805246939,-8.968909731983032,-8.723911104013737,-8.487703306247615,-8.263055659146623,-8.052601950975719,-7.858809559043545,-7.683950521959433,-7.530074902058051,-7.398986750292924,-7.292222955388455,-7.2110352252248315,-7.1563754117075735,-7.128884351174227,-7.12888435 ...

# %%
fig.write_html(file_path + "labevent_embeddings_sphere.html")

# %%
data_without_spheres = []

for i in range(n_clusters):
    cluster_points = vectors_tsne[cluster_labels == i]

    itemid_label_list = [f"{labevent_ids[idx]}: {itemid_to_label.get(str(labevent_ids[idx]), 'Unknown Label')}"
                         for idx in range(len(labevent_ids)) if cluster_labels[idx] == i]

    aggregated_hovertext = "<br>".join(itemid_label_list)

    trace = go.Scatter3d(
        x=cluster_points[:, 0],
        y=cluster_points[:, 1],
        z=cluster_points[:, 2],
        mode='markers',
        marker=dict(
            size=3,
            color=f"rgb({(i * 50) % 255}, {(i * 80) % 255}, {(i * 120) % 255})",
            opacity=0.9
        ),
        name=f"Cluster {i}",
        hovertext=aggregated_hovertext,
        hoverinfo='text'
    )

    data_without_spheres.append(trace)

layout_without_spheres = go.Layout(
    title='3D t-SNE Visualization of Lab Event IDs with KMeans Clusters (Without Spheres)',
    scene=dict(
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        zaxis=dict(title='Dimension 3')
    ),
    showlegend=True,
    hovermode='closest'
)

fig_without_spheres = go.Figure(data=data_without_spheres, layout=layout_without_spheres)
iplot(fig_without_spheres)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8ac71bb1-e765-4de8-aa98-b5c01b617a09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ac71bb1-e765-4de8-aa98-b5c01b617a09")) {                    Plotly.newPlot(                        "8ac71bb1-e765-4de8-aa98-b5c01b617a09",                        [{"hoverinfo":"text","hovertext":"51297: Thrombin\u003cbr\u003e51269: Promyelocytes\u003cbr\u003e51206: Factor VIII\u003cbr\u003e51273: Protein S, Functional\u003cbr\u003e51289: Serum Viscosity\u003cbr\u003e51274: PT\u003cbr\u003e51203: Factor IX\u003cbr\u003e51271: Protein C, Functional\u003cbr\u003e51205: Factor VII\u003cbr\u003e51284: Reticulocyte Count, Manual\u003cbr\u003e51281: Reptilase Time Control\u003cbr\u003e51279: Red Blood Cells\u003cbr\u003e51210: Factor XII\u003cbr\u003e51276: Quantitative G6PD\u003cbr\u003e51277: RDW\u003cbr\u003e51298: Von Willebrand Factor Activity\u003cbr\u003e51282: Reticulocyte Count, Absolute\u003cbr\u003e51299: Von Willebrand Factor Antigen\u003cbr\u003e51204: Factor V\u003cbr\u003e51209: Factor XI\u003cbr\u003e51208: Factor X\u003cbr\u003e51202: Factor II\u003cbr\u003e51288: Sedimentation Rate\u003cbr\u003e51272: Protein S, Antigen\u003cbr\u003e51263: Plasma Cells\u003cbr\u003e51283: Reticulocyte Count, Automated","marker":{"color":"rgb(0, 0, 0)","opacity":0.9,"size":3},"mode":"markers","name":"Cluster 0","x":[-7.355796813964844,-7.018462657928467,-9.70456314086914,-10.779634475708008,-7.629837989807129,-11.628775596618652,-10.307376861572266,-10.099026679992676,-10.734098434448242,-11.26572036743164,-9.958147048950195,-7.090737819671631,-10.418737411499023,-9.317237854003906,-7.844174385070801,-7.627772331237793,-10.496706008911133,-6.84715461730957,-10.926257133483887,-8.438213348388672,-9.273911476135254,-10.208131790161133,-9.112056732177734,-10.911300659179688,-10.939925193786621,-10.382966995239258],"y":[1.1382782459259033,1.6507182121276855,1.7099946737289429,-0.5628662705421448,1.4280272722244263,0.45735689997673035,-0.20985230803489685,0.2514796555042267,1.6575161218643188,0.5025917291641235,0.30528420209884644,1.5213847160339355,2.5219686031341553,1.7865333557128906,0.9675784707069397,1.0333197116851807,0.6663188338279724,1.5986301898956299,0.5904303193092346,1.2866730690002441,0.2543613314628601,0.8898686170578003,-0.1818629652261734,0.6483683586120605,-0.6388384103775024,-0.3319440186023712],"z":[-3.873290538787842,-2.331683874130249,-3.230963706970215,-1.0944843292236328,-2.2916207313537598,-1.795642614364624,-2.0686025619506836,-0.36841902136802673,-2.667121410369873,-2.012136220932007,-0.6943818926811218,-2.583343982696533,-1.1011704206466675,-3.4874322414398193,-3.827094316482544,-2.8684773445129395,-1.2354953289031982,-2.3700718879699707,-2.3327183723449707,-1.9422138929367065,-1.8415517807006836,-1.5989184379577637,-1.7160300016403198,-0.7619535326957703,-1.4536734819412231,-1.4726577997207642],"type":"scatter3d"},{"hoverinfo":"text","hovertext":"50957: Lithium\u003cbr\u003e50870: Anti-Gliadin Antibody, IgA\u003cbr\u003e50946: Human Chorionic Gonadotropin\u003cbr\u003e51749: Treponema pallidum (syphilis) value\u003cbr\u003e50964: Osmolality, Measured\u003cbr\u003e50849: Total Protein, Ascites\u003cbr\u003e51764: EE7\u003cbr\u003e50890: C3\u003cbr\u003e50947: I\u003cbr\u003e51744: Toxoplasma IgM Ab Value\u003cbr\u003e50990: Theophylline\u003cbr\u003e51765: EE3\u003cbr\u003e50966: Phenobarbital\u003cbr\u003e50949: Immunoglobulin A\u003cbr\u003e50840: Cholesterol, Ascites\u003cbr\u003e50980: Rheumatoid Factor\u003cbr\u003e50958: Luteinizing Hormone\u003cbr\u003e50953: Iron Binding Capacity, Total\u003cbr\u003e50950: Immunoglobulin G\u003cbr\u003e50843: Lactate Dehydrogenase, Ascites\u003cbr\u003e50844: Lipase, Ascites\u ...

# %%
cluster_hovertext = {}

for i in range(n_clusters):
    itemid_label_list = [f"{labevent_ids[idx]}: {itemid_to_label.get(str(labevent_ids[idx]), 'Unknown Label')}"
                         for idx in range(len(labevent_ids)) if cluster_labels[idx] == i]

    aggregated_hovertext = "<br>".join(itemid_label_list)

    cluster_hovertext[f"Cluster {i}"] = aggregated_hovertext

df_hovertext = pd.DataFrame.from_dict(cluster_hovertext, orient='index', columns=['Hovertext'])
df_hovertext
# import ace_tools as tools
# tools.display_dataframe_to_user(name="Cluster Hovertexts", dataframe=df_hovertext)
# Out:
#                                                     Hovertext
# Cluster 0   51297: Thrombin<br>51269: Promyelocytes<br>512...
# Cluster 1   50957: Lithium<br>50870: Anti-Gliadin Antibody...
# Cluster 2   50995: Thyroxine (T4), Free<br>51795: Lactate ...
# Cluster 3   51659: HPE3<br>51109: Urine Volume, Total<br>5...
# Cluster 4   51063: Osmolality, Stool<br>51061: Bicarbonate...
# Cluster 5   51667: H. pylori IgG Ab Value<br>50967: Phenyt...
# Cluster 6   51376: Macrophage<br>51516: WBC<br>51356: Unkn...
# Cluster 7   52132: HIT-Ab Numerical Result<br>51011: Unkno...
# Cluster 8   51118: Mesothelial Cell<br>51148: Blasts<br>51...
# Cluster 9   50818: pCO2<br>50813: Lactate<br>51616: Epstei...
# Cluster 10  50864: Alpha-Fetoprotein<br>50994: Thyroxine (...
# Cluster 11  51259: Other Cells<br>51265: Platelet Count<br...
# Cluster 12  50971: Potassium<br>51381: Other<br>50881: Bet...
# Cluster 13  51353: Unknown Label<br>51163: CD16/56%<br>513...
# Cluster 14  51735: STX4<br>51921: proBNP, Pleural<br>50945...
# Cluster 15  52264: Lymphs<br>51494: RBC Casts<br>51364: Un...
# Cluster 16  51360: Unknown Label<br>51110: Atypical Lympho...
# Cluster 17  51492: Protein<br>50902: Chloride<br>51452: NR...
# Cluster 18  51689: Lyme G and M Value<br>51769: RUBIgGV<br...
# Cluster 19  51070: Albumin/Creatinine, Urine<br>51047: Amy...
# Cluster 20  51006: Urea Nitrogen<br>50906: Cholesterol, LD...
# Cluster 21  51095: Phosphate, Urine<br>51345: Unknown Labe...
# Cluster 22  50853: 25-OH Vitamin D<br>50973: Prolactin<br>...
# Cluster 23  51099: Protein/Creatinine Ratio<br>52069: Abso...

# %% [markdown]
# ### **Visualize embedding with t-SNE**

# %%
# import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# reduce to 3d using t-SNE
tsne = TSNE(n_components=3, random_state=42)
vectors_tsne = tsne.fit_transform(vectors_pca)

# %%
query = """
    SELECT
        itemid,
        label
    FROM
        `physionet-data.mimiciv_hosp.d_labitems`
"""

df_labitems = bf.read_gbq(query).to_pandas()
print(len(df_labitems))
print(df_labitems.head(1))
# Out:
# Query job 5167b79a-9aa4-4c48-bd9a-3b3cc9807b81 is DONE. 36.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:5167b79a-9aa4-4c48-bd9a-3b3cc9807b81&page=queryresults">Open Job</a>
# Query job c1e3b6b8-f5ed-4b03-97fb-e64b90c38fad is DONE. 36.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=hellobigquery-431508&j=bq:US:c1e3b6b8-f5ed-4b03-97fb-e64b90c38fad&page=queryresults">Open Job</a>
# 1622
#    itemid  label
# 0   52397  FL2-D

# %%
# labevent_ids = list(labevent_vectors.index_to_key)
# itemid_to_label = dict(zip(df_labitems['itemid'], df_labitems['label']))
# print(itemid_to_label)

itemid_to_label = dict(zip(df_labitems['itemid'].astype(str), df_labitems['label']))

itemid_label_list = [f"{itemid}: {itemid_to_label.get(str(itemid), 'Unknown Label')}" for itemid in labevent_ids]

trace = go.Scatter3d(
    x=vectors_tsne[:, 0],
    y=vectors_tsne[:, 1],
    z=vectors_tsne[:, 2],
    mode='markers',
    marker=dict(
        size=3,
        color='rgba(255, 128, 2, 0.8)',  # Marker color
    ),
    text=itemid_label_list
)

data = [trace]

layout = go.Layout(
    title='3D t-SNE Visualization of Lab Event IDs',
    scene=dict(
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        zaxis=dict(title='Dimension 3')
    )
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="29a09232-3133-4c41-a605-722088560790" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29a09232-3133-4c41-a605-722088560790")) {                    Plotly.newPlot(                        "29a09232-3133-4c41-a605-722088560790",                        [{"marker":{"color":"rgba(255, 128, 2, 0.8)","size":3},"mode":"markers","text":["51735: STX4","50818: pCO2","50813: Lactate","51297: Thrombin","50853: 25-OH Vitamin D","51259: Other Cells","51269: Promyelocytes","51921: proBNP, Pleural","50957: Lithium","51063: Osmolality, Stool","51265: Platelet Count","51206: Factor VIII","51006: Urea Nitrogen","51659: HPE3","51492: Protein","51246: Macrocytes","51376: Macrophage","51516: WBC","51667: H. pylori IgG Ab Value","50870: Anti-Gliadin Antibody, IgA","51070: Albumin\u002fCreatinine, Urine","51689: Lyme G and M Value","52132: HIT-Ab Numerical Result","51095: Phosphate, Urine","51118: Mesothelial Cell","50945: Homocysteine","51345: Unknown Label","51125: Polys","51273: Protein S, Functional","50902: Chloride","50967: Phenytoin","51047: Amylase, Pleural","52177: SCT - Confirmation","50946: Human Chorionic Gonadotropin","51109: Urine Volume, Total","51245: Lymphocytes, Percent","50924: Ferritin","51360: Unknown Label","51289: Serum Viscosity","51054: Lactate Dehydrogenase, Pleural","51749: Treponema pallidum (syphilis) value","51353: Unknown Label","51110: Atypical Lymphocytes","51011: Unknown Label","51020: Amylase, Joint Fluid","50906: Cholesterol, LDL, Measured","51726: Rubeola IgG Ab Value","51248: MCH","51127: RBC, Ascites","51447: Macrophages","50864: Alpha-Fetoprotein","52264: Lymphs","50841: Creatinine, Ascites","50971: Potassium","51014: Unknown Label","51494: RBC Casts","51148: Blasts","51218: Granulocyte Count","50973: Prolactin","51128: Unknown Label","51452: NRBC","51767: EE5","51280: Reptilase Time","51222: Hemoglobin","51105: Uric Acid, Urine","51440: Atypical Lymphocytes","50964: Osmolality, Measured","51616: Epstein-Barr Virus IgG Ab Value","51457: RBC, Pleural","51244: Lymphocytes","51274: PT","51001: Triiodothyronine (T3)","51381: Other","52075: Absolute Neutrophil Count","51115: Hematocrit, Ascites","51369: Hematocrit, Joint Fluid","51065: Sodium, Stool","51356: Unknown Label","50881: Beta-2 Microglobulin","51166: CD19 Absolute Count","50922: Ethanol","51203: Factor IX","51163: CD16\u002f56%","52129: Hemoglobin Other","51271: Protein C, Functional","51769: RUBIgGV","51087: Length of Urine Collection","51358: Unknown Label","51010: Vitamin B12","50849: Total Protein, Ascites","51205: Factor VII","51764: EE7","51379: Monocytes","50994: Thyroxine (T4)","50896: Calculated Thyroxine (T4) Index","51497: Renal Epithelial Cells","51176: CD3 Cells, Percent","51284: Reticulocyte Count, Manual","51122: Nucleated RBC","50890: C3","51441: Bands","52369: Total Nucleated Cells, Other","51061: Bicarbonate, Stool","51515: Waxy Casts","50914: Cyclosporin","51364: Unknown Label","51064: Potassium, Stool","50947: I","52135: Immature Granulocytes","51249: MCHC","50836: Amylase, Ascites","51281: Reptilase Time Control","52391: Total Nucleated Cells, Pleural","51491: pH","51254: Monocytes","51226: Hemogloblin A","51652: High-Sensitivity CRP","51387: Basophils","50894: Calculated Free Testosterone","51165: CD19 %","52257: Hematocrit, CSF","50814: Methemoglobin","50961: Methotrexate","51000: Triglycerides","51007: Uric Acid","51455: Polys","51660: HPE4","51252: Microcytes","51237: INR(PT)","51363: Unknown Label","51627: Free Lambda","50817: Oxygen Saturation","51422: Hematocrit, Other Fluid","51355: Unknown Label","51102: Total Protein, Urine","51744: Toxoplasma IgM Ab Value","51357: Unknown Label","50852: % Hemoglobin A1c","50816: Oxygen ...

# %% [markdown]
# **save**

# %%
fig.write_html(file_path + "labevent_embeddings.html")

# %%
# create a dict to convert itemid to embedding vector
itemid_to_vector = {str(itemid): vector for itemid, vector in zip(labevent_ids, vectors_pca)}
print(len(itemid_to_vector))

df_itemid_to_vector = pd.DataFrame.from_dict(itemid_to_vector, orient='index')
df_itemid_to_vector.reset_index(inplace=True)

df_itemid_to_vector.columns = ['itemid'] + [f'vector_{i}' for i in range(df_itemid_to_vector.shape[1] - 1)]
print(len(df_itemid_to_vector))
df_itemid_to_vector.head(1)
# Out:
# 502
# 502
#   itemid  vector_0  vector_1  vector_2  vector_3  vector_4  vector_5  \
# 0  51735  1.621916  0.149717  0.695458 -0.874585 -0.423603 -0.567098
#
#    vector_6  vector_7  vector_8  ...  vector_10  vector_11  vector_12  \
# 0 -0.270054  0.008114 -1.044646  ...   -0.56414  -0.486858   0.607975
#
#    vector_13  vector_14  vector_15  vector_16  vector_17  vector_18  vector_19
# 0  -0.190866   0.118577   0.153755  -0.936731  -0.220527  -0.227966   0.075255
#
# [1 rows x 21 columns]

# %%
# df_itemid_to_vector.to_csv(file_path + 'itemid_to_vector_2.csv', index=False)
# df_itemid_to_vector.to_csv(file_path + 'itemid_to_vector_all.csv', index=False)
